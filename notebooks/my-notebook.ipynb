# %%
from IPython.display import Audio, Image, YouTubeVideo, Video

# %%
id = 'ER4WhBxM8DY'
YouTubeVideo(id=id)

# %%
Video('images/intro-jupyter-create-notebook-06.mp4')
# Out:
# <video src="images/intro-jupyter-create-notebook-06.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
